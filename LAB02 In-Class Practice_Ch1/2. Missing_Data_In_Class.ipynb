# %% [markdown]
# # **A. MISSING DATA**
#
# ---
#
#
#
# > Identifying and Handling Missing Data.

# %% [markdown]
# **STEP 1. LIBRARIES**
#
# ---

# %%
# import libraries

# %% [markdown]
# **STEP 2. DATASET**
#
# ---

# %%
# generate a dataset
# understanding this line of code is not required
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
# show the dataset

# %% [markdown]
# **STEP 3. DETECTING MISSING DATA**
#
# ---

# %%
# "isnull" identifies missing values
# the first "sum()" calculates the total number of missing values per column
# the second "sum()" calculates the total number of missing values per row

# %%
# show the count of missing values per column

# %%
# alternatively - show the count of missing values per column

# %%
# show the count of missing values per row

# %% [markdown]
# **STEP 4. ADDRESSING MISSING DATA**
#
# ---

# %% [markdown]
# **1. MISSING VALUES REMOVAL**

# %%
# "drop" is the command for deleting
# "na" stands for "not available" and refers to missing values
# this line of code removes all rows with missing values
# "axis=0" is optional in this case

# %%
# this line of code removes all columns with missing values

# %% [markdown]
# ---

# %% [markdown]
# **2. MISSING VALUES IMPUTATION**

# %%
# "fill" is used for imputation
# "na" is used to indicate missing values
# "A" is the name of the variable (i.e., the column label)
# "median" can be used instead of "mean"

# %%
# since there can be multiple modes,
# [0] selects the first mode in the list,
# [1] selects the second mode, and so forth.

# %% [markdown]
# ---

# %% [markdown]
# **3. MAKING PERMANENT CHANGES**
#
#
# In this example, we will use the mean to permanently impute the missing values.

# %%
# "inplace=True" ensures that changes are applied permanently to the dataset

# %%
# display the entire dataset after applying the changes

# %% [markdown]
# ---

# %% [markdown]
# # Good Job !
