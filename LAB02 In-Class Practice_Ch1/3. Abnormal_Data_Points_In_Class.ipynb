# %% [markdown]
# # **B. ABNORMAL DATA POINTS**
#
# ---
#
#
#
# > Identifying and Handling Abnormal Data Points.

# %% [markdown]
# **STEP 1. LIBRARIES**
#
# ---

# %%
# import libraries

# %% [markdown]
# **STEP 2. DATASET**
#
# ---

# %%
# import "weight-height.csv"

# %%
# read the data

# %%
# show the dataset

# %%
# for quick descriptive statistics

# %% [markdown]
# **STEP 3. DETECTING ABNORMAL DATA POINTS**
#
# ---

# %% [markdown]
# **1. GRAPHICAL DETECTION**

# %%
# libraries

# %%
# boxplot

# %% [markdown]
# ---

# %%
# used to specify the number of bins (optional)


# histogram

# %% [markdown]
# ---

# %%
# specify the variables on the x-axis


# specify the variables on the y-axis


# scatter plot

# %% [markdown]
# ---

# %% [markdown]
# **2. MATHEMATICAL DETECTION**

# %%
# STEP 1. QUARTILES
# to calculate the first quartile


# to calculate the third quartile


# to show the calculated quartiles

# %%
# STEP 2. INTERQUARTILE RANGE
# to calculate the interquartile range


# to show the calculated interquartile range

# %%
# STEP 3. LIMITS
# to calculate the lower limit


# to calculate the upper limit


# to show the calculated limits

# %%
# STEP 4. ABNORMAL POINTS DETECTION
# to show points that are outside the limits

# %% [markdown]
# ---

# %% [markdown]
# **STEP 4. ADDRESSING ABNORMAL POINTS**
#
# ---

# %% [markdown]
# **1. ABNORMAL POINTS REMOVAL**

# %%
# STEP 5. ABNORMAL POINTS REMOVAL
# to create a new dataset (i.e., df2) containing only values within the limits

# %% [markdown]
# ---

# %% [markdown]
# **2. ABNORMAL POINTS MODIFICATION**

# %%
# the dataset before any transformation

# %%
# number of missing values per variable BEFORE removing abnormal points

# %% [markdown]
# ---

# %%
# STEP 5. ABNORMAL POINTS REMOVAL
# remove abnormal points and report the resulting empty cells as missing values
# "loc" is used to locate and update specific rows and columns in a DataFrame
# based on a condition (i.e., outside of the limits in this case)
# "Height" is used to target the Height column
# Therefore, this line uses "loc" to set the Height values to NaN for any rows
# where the height is outside of the defined limits

# %%
# number of missing values per variable AFTER removing abnormal points

# %% [markdown]
# ---

# %%
# STEP 6. MISSING VALUES IMPUTATION

# %%
# number of missing values per variable AFTER imputing missing values

# %% [markdown]
# ---

# %% [markdown]
# # Good Job !
