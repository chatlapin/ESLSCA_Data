# %% [markdown]
# # **C. IMBALANCED DATASETS**
#
# ---

# %% [markdown]
# Identifying and Addressing Imbalanced Datasets.

# %% [markdown]
# ---

# %% [markdown]
# # **I. CHECKING CLASS DISTRIBUTION**
#
# ---

# %%
# STEP 1. IMPORT THE "creditcard_fraud.csv" DATASET

# %%
# STEP 2. READ THE DATA

# %%
# STEP 3. TARGET AND FEATURES IDENTIFICATION
# identify the features (i.e., the independent variables "x")


# identify the target (i.e., the dependent variable "y")

# %%
# STEP 4. CLASS DISTRIBUTION
# class 0 = no fraud
# class 1 = fraud

# %%
# no need to import matplotlib since pandas also provides pie charts
# "autopct='%.2f'" is used to limit the number of decimal places to 2

# %% [markdown]
# # **II. ADDRESSING CLASS IMBALANCE**
#
# ---

# %%
# STEP 1. INSTALL THE "IMBALANCED LEARN" LIBRARY

# %% [markdown]
# ---

# %% [markdown]
# **1. RANDOM UNDER-SAMPLING**
#
# ---

# %%
# STEP 2. IMPORT NECESSARY LIBRARIES

# %%
# STEP 3. DEFINE THE SAMPLING STRATEGY = RUS
# "sampling_strategy="not minority"" specifies that undersampling should be
# applied to all classes except the minority class, thereby balancing the
# dataset by reducing the size of the majority class

# %%
# STEP 4. RESAMPLE THE DATASET

# %%
# updated class distribution

# %%
# updated class distribution - graph

# %%
# STEP 5. GENERATE A NEW BALANCED DATASET

# %% [markdown]
# ---

# %% [markdown]
# **2. RANDOM OVER-SAMPLING**
#
# ---

# %%
# STEP 2. IMPORT NECESSARY LIBRARIES

# %%
# STEP 3. DEFINE THE SAMPLING STRATEGY = ROS
# "sampling_strategy="not majority"" specifies that oversampling should be
# applied to all classes except the majority class, thereby balancing the
# dataset by increasing the size of the minority class

# %%
# STEP 4. RESAMPLE THE DATASET

# %%
# updated class distribution

# %%
# updated class distribution - graph

# %%
# STEP 5. GENERATE A NEW BALANCED DATASET

# %% [markdown]
# ---
